# %% [markdown]
# ## EDA
# #### Importing libraries

# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_column', 55)

# %%
#Getting Data
df = pd.read_csv('public_150k_plus_220703.csv')

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription       ProjectCity ProjectCountyName  \
# 0  Existing or more than 2 years old            Sumter            SUMTER
# 1  Existing or more than 2 years old  North Charleston        CHARLESTON
# 2    New Business or 2 years or less           SEATTLE              KING
# 3    New Business or 2 years or less    SAN BERNARDINO    SAN BERNARDINO
# 4                         Unanswered               NaN               NaN
#
#   ProjectState  ProjectZip     CD  JobsReported  NAICSCode  \
# 0           SC  29150-9662  SC-05          62.0   325510.0
# 1           SC  29420-9000  SC-06          73.0   561730.0
# 2           WA  98112-2922  WA-07          75.0        NaN
# 3           CA  92407-1740  CA-08          21.0   236115.0
# 4          NaN         NaN    NaN          25.0   484210.0
#
#                                Race               Ethnicity  \
# 0                        Unanswered       Unknown/NotStated
# 1                             White       Unknown/NotStated
# 2                        Unanswered       Unknown/NotStated
# 3  American Indian or Alaska Native  Not Hispanic or Latino
# 4                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  \
# 0                NaN        769358.78                        NaN
# 1                NaN        736927.79                        NaN
# 2                NaN        691355.00                        NaN
# 3                NaN        499871.00                        NaN
# 4                NaN        367437.00                        NaN
#
#    RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  \
# 0           NaN                     NaN                  NaN
# 1           NaN                     NaN                  NaN
# 2           NaN                     NaN                  NaN
# 3           NaN                     NaN                  NaN
# 4           NaN                     NaN                  NaN
#
#    DEBT_INTEREST_PROCEED             BusinessType  \
# 0                    NaN              Corporation
# 1                    NaN      Sole Proprietorship
# 2                    NaN  Non-Profit Organization
# 3                    NaN              Corporation
# 4                    NaN                      NaN
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                        19248                           Synovus Bank
# 1                        19248                           Synovus Bank
# 2                         9551  Bank of America, National Association
# 3                         9551  Bank of America, National Association
# 4                        57328           The Huntington National Bank
#
#   OriginatingLenderCity OriginatingLenderState      Gender      Veteran  \
# 0              COLUMBUS                     GA  Unanswered   Unanswered
# 1              COLUMBUS                     GA  Male Owned  Non-Veteran
# 2             CHARLOTTE                     NC  Unanswered   Unanswered
# 3             CHARLOTTE                     NC  Male Owned  Non-Veteran
# 4              COLUMBUS                     OH  Unanswered   Unanswered
#
#   NonProfit  ForgivenessAmount ForgivenessDate
# 0       NaN          773553.37      11/20/2020
# 1       NaN          746336.24      08/12/2021
# 2         Y          696677.49      02/10/2021
# 3       NaN          395264.11      09/10/2021
# 4       NaN          370819.35      04/08/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968532 entries, 0 to 968531
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968532 non-null  int64
#  1   DateApproved                 968532 non-null  object
#  2   SBAOfficeCode                968532 non-null  int64
#  3   ProcessingMethod             968532 non-null  object
#  4   BorrowerName                 968528 non-null  object
#  5   BorrowerAddress              968518 non-null  object
#  6   BorrowerCity                 968520 non-null  object
#  7   BorrowerState                968519 non-null  object
#  8   BorrowerZip                  968519 non-null  object
#  9   LoanStatusDate               896656 non-null  object
#  10  LoanStatus                   968532 non-null  object
#  11  Term                         968532 non-null  int64
#  12  SBAGuarantyPercentage        968532 non-null  int64
#  13  InitialApprovalAmount        968532 non-null  float64
#  14  CurrentApprovalAmount        968532 non-null  float64
#  15  UndisbursedAmount            968470 non-null  float64
#  16  FranchiseName                35405 non-null   object
#  17  ServicingLenderLocationID    968532 non-null  int64
#  18  ServicingLenderName          968532 non-null  object
#  19  ServicingLenderAddress       968532 non-null  object
#  20  ServicingLenderCity          968532 non-null  object
#  21  ServicingLenderState         968532 non-null  object
#  22  ServicingLenderZip           968532 non-null  object
#  23  RuralUrbanIndicator          968532 non-null  object
#  24  HubzoneIndicator             968532 non-null  object
#  25  LMIIndicator                 968532 non-null  object
#  26  BusinessAgeDescription       968531 non-null  object
#  27  ProjectCity                  968519 non-null  object
#  28  ProjectCountyName            968475 non-null  object
#  29  ProjectState                 968523 non-null  object
#  30  ProjectZip                   968518 non-null  object
#  31  CD                           968486 non-null  object
#  32  JobsReported                 968531 non-null  float64
#  33  NAICSCode                    961904 non-null  float64
#  34  Race                         968532 non-null  object
#  35  Ethnicity                    968532 non-null  object
#  36  UTILITIES_PROCEED            339400 non-null  float64
#  37  PAYROLL_PROCEED              966701 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    46241 non-null   float64
#  39  RENT_PROCEED                 99550 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       22907 non-null   float64
#  41  HEALTH_CARE_PROCEED          57470 non-null   float64
#  42  DEBT_INTEREST_PROCEED        31760 non-null   float64
#  43  BusinessType                 967810 non-null  object
#  44  OriginatingLenderLocationID  968532 non-null  int64
#  45  OriginatingLender            968532 non-null  object
#  46  OriginatingLenderCity        968532 non-null  object
#  47  OriginatingLenderState       968532 non-null  object
#  48  Gender                       968532 non-null  object
#  49  Veteran                      968532 non-null  object
#  50  NonProfit                    59339 non-null   object
#  51  ForgivenessAmount            916440 non-null  float64
#  52  ForgivenessDate              916440 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 391.6+ MB

# %%
#checking for nulls
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerAddress                    14
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  71876
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  62
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              1
# ProjectCity                        13
# ProjectCountyName                  57
# ProjectState                        9
# ProjectZip                         14
# CD                                 46
# JobsReported                        1
# NAICSCode                        6628
# Race                                0
# Ethnicity                           0
# UTILITIES_PROCEED              629132
# PAYROLL_PROCEED                  1831
# MORTGAGE_INTEREST_PROCEED      922291
# RENT_PROCEED                   868982
# REFINANCE_EIDL_PROCEED         945625
# HEALTH_CARE_PROCEED            911062
# DEBT_INTEREST_PROCEED          936772
# BusinessType                      722
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# Gender                              0
# Veteran                             0
# NonProfit                      909193
# ForgivenessAmount               52092
# ForgivenessDate                 52092
# dtype: int64

# %%
df = df.loc[df['BorrowerName'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 968528 entries, 0 to 968531
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968528 non-null  int64
#  1   DateApproved                 968528 non-null  object
#  2   SBAOfficeCode                968528 non-null  int64
#  3   ProcessingMethod             968528 non-null  object
#  4   BorrowerName                 968528 non-null  object
#  5   BorrowerAddress              968514 non-null  object
#  6   BorrowerCity                 968516 non-null  object
#  7   BorrowerState                968515 non-null  object
#  8   BorrowerZip                  968515 non-null  object
#  9   LoanStatusDate               896653 non-null  object
#  10  LoanStatus                   968528 non-null  object
#  11  Term                         968528 non-null  int64
#  12  SBAGuarantyPercentage        968528 non-null  int64
#  13  InitialApprovalAmount        968528 non-null  float64
#  14  CurrentApprovalAmount        968528 non-null  float64
#  15  UndisbursedAmount            968466 non-null  float64
#  16  FranchiseName                35405 non-null   object
#  17  ServicingLenderLocationID    968528 non-null  int64
#  18  ServicingLenderName          968528 non-null  object
#  19  ServicingLenderAddress       968528 non-null  object
#  20  ServicingLenderCity          968528 non-null  object
#  21  ServicingLenderState         968528 non-null  object
#  22  ServicingLenderZip           968528 non-null  object
#  23  RuralUrbanIndicator          968528 non-null  object
#  24  HubzoneIndicator             968528 non-null  object
#  25  LMIIndicator                 968528 non-null  object
#  26  BusinessAgeDescription       968527 non-null  object
#  27  ProjectCity                  968515 non-null  object
#  28  ProjectCountyName            968471 non-null  object
#  29  ProjectState                 968519 non-null  object
#  30  ProjectZip                   968514 non-null  object
#  31  CD                           968482 non-null  object
#  32  JobsReported                 968527 non-null  float64
#  33  NAICSCode                    961900 non-null  float64
#  34  Race                         968528 non-null  object
#  35  Ethnicity                    968528 non-null  object
#  36  UTILITIES_PROCEED            339396 non-null  float64
#  37  PAYROLL_PROCEED              966697 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    46241 non-null   float64
#  39  RENT_PROCEED                 99550 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       22907 non-null   float64
#  41  HEALTH_CARE_PROCEED          57470 non-null   float64
#  42  DEBT_INTEREST_PROCEED        31760 non-null   float64
#  43  BusinessType                 967806 non-null  object
#  44  OriginatingLenderLocationID  968528 non-null  int64
#  45  OriginatingLender            968528 non-null  object
#  46  OriginatingLenderCity        968528 non-null  object
#  47  OriginatingLenderState       968528 non-null  object
#  48  Gender                       968528 non-null  object
#  49  Veteran                      968528 non-null  object
#  50  NonProfit                    59337 non-null   object
#  51  ForgivenessAmount            916437 non-null  float64
#  52  ForgivenessDate              916437 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 399.0+ MB

# %%
#add a few more columns to our df for analysis
df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  29150-9662  SC-05         62.0
# 1  Existing or more than 2 years old  ...  29420-9000  SC-06         73.0
# 2    New Business or 2 years or less  ...  98112-2922  WA-07         75.0
# 3    New Business or 2 years or less  ...  92407-1740  CA-08         21.0
# 4                         Unanswered  ...         NaN    NaN         25.0
#
#   NAICSCode                              Race               Ethnicity  \
# 0  325510.0                        Unanswered       Unknown/NotStated
# 1  561730.0                             White       Unknown/NotStated
# 2       NaN                        Unanswered       Unknown/NotStated
# 3  236115.0  American Indian or Alaska Native  Not Hispanic or Latino
# 4  484210.0                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0                NaN       769358.78                       NaN           NaN
# 1                NaN       736927.79                       NaN           NaN
# 2                NaN       691355.00                       NaN           NaN
# 3                NaN       499871.00                       NaN           NaN
# 4                NaN       367437.00                       NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
#
#               BusinessType  OriginatingLenderLocationID  \
# 0              Corporation                        19248
# 1      Sole Proprietorship                        19248
# 2  Non-Profit Organization                         9551
# 3              Corporation                         9551
# 4                      NaN                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      GA  Unanswered   Unanswered       NaN
# 1                      GA  Male Owned  Non-Veteran       NaN
# 2                      NC  Unanswered   Unanswered         Y
# 3                      NC  Male Owned  Non-Veteran       NaN
# 4                      OH  Unanswered   Unanswered       NaN
#
#   ForgivenessAmount ForgivenessDate year_approved  month_approved  \
# 0         773553.37      11/20/2020          2020               5
# 1         746336.24      08/12/2021          2020               5
# 2         696677.49      02/10/2021          2020               5
# 3         395264.11      09/10/2021          2020               5
# 4         370819.35      04/08/2021          2020               5
#
#   year_forgiven  month_forgiven
# 0        2020.0            11.0
# 1        2021.0             8.0
# 2        2021.0             2.0
# 3        2021.0             9.0
# 4        2021.0             4.0
#
# [5 rows x 57 columns]

# %%
FirstRound = df.loc[ df['ProcessingMethod'] == 'PPP']

# %%
SecondRound = df.loc[ df['ProcessingMethod'] == 'PPS']

# %%
FirstRound.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  29150-9662  SC-05         62.0
# 1  Existing or more than 2 years old  ...  29420-9000  SC-06         73.0
# 2    New Business or 2 years or less  ...  98112-2922  WA-07         75.0
# 3    New Business or 2 years or less  ...  92407-1740  CA-08         21.0
# 4                         Unanswered  ...         NaN    NaN         25.0
#
#   NAICSCode                              Race               Ethnicity  \
# 0  325510.0                        Unanswered       Unknown/NotStated
# 1  561730.0                             White       Unknown/NotStated
# 2       NaN                        Unanswered       Unknown/NotStated
# 3  236115.0  American Indian or Alaska Native  Not Hispanic or Latino
# 4  484210.0                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0                NaN       769358.78                       NaN           NaN
# 1                NaN       736927.79                       NaN           NaN
# 2                NaN       691355.00                       NaN           NaN
# 3                NaN       499871.00                       NaN           NaN
# 4                NaN       367437.00                       NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
#
#               BusinessType  OriginatingLenderLocationID  \
# 0              Corporation                        19248
# 1      Sole Proprietorship                        19248
# 2  Non-Profit Organization                         9551
# 3              Corporation                         9551
# 4                      NaN                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      GA  Unanswered   Unanswered       NaN
# 1                      GA  Male Owned  Non-Veteran       NaN
# 2                      NC  Unanswered   Unanswered         Y
# 3                      NC  Male Owned  Non-Veteran       NaN
# 4                      OH  Unanswered   Unanswered       NaN
#
#   ForgivenessAmount ForgivenessDate year_approved  month_approved  \
# 0         773553.37      11/20/2020          2020               5
# 1         746336.24      08/12/2021          2020               5
# 2         696677.49      02/10/2021          2020               5
# 3         395264.11      09/10/2021          2020               5
# 4         370819.35      04/08/2021          2020               5
#
#   year_forgiven  month_forgiven
# 0        2020.0            11.0
# 1        2021.0             8.0
# 2        2021.0             2.0
# 3        2021.0             9.0
# 4        2021.0             4.0
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Categorical Variables
# ### Univariable

# %%
## count the how many records there are in each processing method
sns.countplot(df['ProcessingMethod'])
# Out:
# C:\Users\Pc 1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %%
sns.countplot(df['BorrowerState'])
# Out:
# C:\Users\Pc 1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BorrowerState', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# C:\Users\Pc 1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
sns.countplot(df['Ethnicity'])
# Out:
# C:\Users\Pc 1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
##Rotate the ticklabels
plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high to became more bigger
ax = sns.countplot(x="BusinessType", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
plt.show()

# %%
##Rotate the ticklabels
ax = sns.countplot(x="Race", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
plt.show()

# %% [markdown]
# ## BiVariate

# %%
## Plotting Ethnicity Against Loan Status
sns.countplot(x = 'Ethnicity' , hue ='LoanStatus' , data = df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#cross tabulation
pd.crosstab(df['BorrowerState'],df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# AK                             45                     689               1928
# AL                             49                    3230               7633
# AR                             55                    1521               4281
# AS                              0                       1                 19
# AZ                            450                    3578              11766
# CA                           5863                   36338              88413
# CO                            463                    5047              14233
# CT                            167                    3295               9430
# DC                             97                     905               3397
# DE                             36                     859               2101
# FL                           3218                   11538              45280
# GA                            390                    6751              18691
# GU                              4                     152                287
# HI                             93                    1321               3566
# IA                             70                    3084               5141
# ID                             56                    1037               3323
# IL                            631                   10346              29837
# IN                             96                    4963              11541
# KS                             71                    2339               5792
# KY                             59                    2587               6532
# LA                            152                    3045              10471
# MA                            437                    8188              18848
# MD                            247                    4402              14329
# ME                             16                    1144               3025
# MI                            196                    7860              21745
# MN                            146                    6567              13016
# MO                            119                    4766              11465
# MP                              2                      32                 48
# MS                             33                    2012               3457
# MT                             11                    1092               2041
# NC                            168                    3941              18719
# ND                             23                    1409               1790
# NE                             55                    2134               3615
# NH                             34                    1389               3655
# NJ                            517                    6994              25023
# NM                            470                     963               3051
# NV                            278                    2161               5822
# NY                           1227                   17468              55414
# OH                            235                   11826              20585
# OK                            127                    2665               7205
# OR                            196                    3241              10018
# PA                            231                    9959              28345
# PR                            993                      42               1917
# RI                             79                    1266               2447
# SC                             47                    2149               8546
# SD                              8                     874               1813
# TN                            114                    3388              12367
# TX                           3971                   18788              53425
# UT                            149                    2628               6517
# VA                            325                    4690              18253
# VI                              8                      87                195
# VT                              6                     555               1708
# WA                            407                    6039              17307
# WI                            103                    5050              12200
# WV                             26                    1018               2321
# WY                             26                     641               1472

# %%
pd.crosstab(df['year_approved'], df['BorrowerState'])
# Out:
# BorrowerState    AK    AL    AR  AS     AZ     CA     CO    CT    DC    DE  \
# year_approved
# 2020           1713  7840  4254  18  11314  87334  13413  8585  2798  2066
# 2021            949  3072  1603   2   4480  43280   6330  4307  1601   930
#
# BorrowerState     FL     GA   GU    HI    IA    ID     IL     IN    KS    KY  \
# year_approved
# 2020           41555  18124  289  3180  5953  3315  27320  11853  5884  6440
# 2021           18481   7708  154  1800  2342  1101  13494   4747  2318  2738
#
# BorrowerState    LA     MA     MD    ME     MI     MN     MO  ...    MT  \
# year_approved                                                 ...
# 2020           9061  18206  12843  2874  19881  13725  11491  ...  2203
# 2021           4607   9267   6135  1311   9920   6004   4859  ...   941
#
# BorrowerState     NC    ND    NE    NH     NJ    NM    NV     NY     OH    OK  \
# year_approved
# 2020           16118  2188  4186  3442  21868  3014  5553  46903  22873  6841
# 2021            6710  1034  1618  1636  10666  1470  2708  27206   9773  3156
#
# BorrowerState    OR     PA    PR    RI    SC    SD     TN     TX    UT     VA  \
# year_approved
# 2020           9283  26018  1940  2470  7584  1955  11283  51888  6745  16111
# 2021           4172  12517  1012  1322  3158   740   4586  24296  2549   7157
#
# BorrowerState   VI    VT     WA     WI    WV    WY
# year_approved
# 2020           173  1547  15940  12378  2288  1360
# 2021           117   722   7813   4975  1077   779
#
# [2 rows x 56 columns]

# %%
pd.crosstab(df['Ethnicity'],df['LoanStatus'])
# Out:
# LoanStatus              Active Un-Disbursed  Exemption 4  Paid in Full
# Ethnicity
# Hispanic or Latino                        0         3061         20034
# Not Hispanic or Latino                    7        19624        230424
# Unknown/NotStated                         5        49190        646183

# %% [markdown]
# ## Numerical Variables - Discrete Variable

# %%
## Descriptive Summary
df['CurrentApprovalAmount'].describe()
# Out:
# count    9.685280e+05
# mean     5.306222e+05
# std      7.378880e+05
# min      1.500000e+05
# 25%      2.004000e+05
# 50%      2.950000e+05
# 75%      5.393815e+05
# max      1.000000e+07
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ## Outliers
#
# ### The five-number summary

# %%
sns.boxplot(x = df['CurrentApprovalAmount'])
#after0.0 we call this the minimum than 25%,50%,75% after that we call it the maximum than the outliers
# Out:
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %%
##The five-number summary divides the data into sections that each contain approximately 25 percent of the data in that set.
#The five-number summary is the minimum, first quartile, median, third quartile, and maximum

# Min = Minimum value
# Q1 = The first quartile is the median of the data points to the left of the median
# Median = is the value separating the higher half from the lower half of a data sample, a population or distribution
# Q3 = The third quartile is the median of the data points to the right of the median
# Max = Max value

#About 75 percent of the CurrentApprovalAmount is greater than 8700 dollars per the boxplot above.

# %%
plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high
sns.boxplot(x="LoanStatus", y="CurrentApprovalAmount", data=df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sns.distplot(df['CurrentApprovalAmount']/10**3)
# Out:
# C:\Users\Pc 1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CurrentApprovalAmount', ylabel='Density'>

# %%
#Deviates from the normal distribution.
#Have a positive skewness.

#skewness and kurtosis
#Basically getting the body measure of the above diagram

# %%
#df['CurrentApprovalAmount'].skew()
#df['CurrentApprovalAmount'].kurt()

###Modified as compared to what I showed in Demo
print("Skewness: %f" % df['CurrentApprovalAmount'].skew())
print("Kurtosis: %f" % df['CurrentApprovalAmount'].kurt())
# Out:
# Skewness: 5.759147
# Kurtosis: 48.973898

# %%
#scatter plot ForgivenessAmount/CurrentApprovalAmount
var = 'ForgivenessAmount'
data = pd.concat([df['CurrentApprovalAmount'], df[var]], axis=1)
data.plot.scatter(x='CurrentApprovalAmount', y=var);

# %% [markdown]
# ## Correlation

# %%
##correlation matrix
matrix = df.corr()
f, ax = plt.subplots(figsize=(15, 11))
sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>
